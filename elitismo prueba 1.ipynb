# %%
import random
from random import randint
#funciones
def aleatorios(n):
    return random.randrange(1,100)
def f(x,y):
    return (x**2*(y))+(y**2*(x))
def imprimir(tab):
    print("x\t\ty\t\t f(x,y)\t\tgrado de pertenencia \t\tbinario")
    for i in range(10):
        print(str(tabla[0][i])+"\t\t",end="")
        print(str(tabla[1][i])+"\t\t",end="")
        print(str(tabla[2][i])+"\t\t",end="")
        print(str(tabla[3][i])+"\t\t\t\t",end="")
        print(str(tabla[4][i]))
    print()
def SelectionSort(tabla):
    #Ordenar con el metodo de selection sort
    for i in range(10):
        valorMaximo=0
        posicionMaximo=0
        j=i
        while j<10:
            if tabla[2][j]>valorMaximo:
                valorMaximo=tabla[2][j]
                posicionMaximo=j
            j+=1
        tabla[0][i],tabla[0][posicionMaximo]=tabla[0][posicionMaximo],tabla[0][i]
        tabla[1][i],tabla[1][posicionMaximo]=tabla[1][posicionMaximo],tabla[1][i]
        tabla[2][i],tabla[2][posicionMaximo]=tabla[2][posicionMaximo],tabla[2][i]

    
    
def CalcularGrado(tabla):
    sumatoria=0
    for valor in tabla[2]:
        sumatoria+=valor
    i=0   
    while i<10:
        tabla[3][i]=round(tabla[2][i]/sumatoria,5)
        i=i+1
def suma(lista):
    s=0
    for i in range (10):
        s=s+(tabla[3][i])
    return s
def ConvertirColumnaABinario(tabla):
    i=0
    while i<10:
        tabla[4][i]=conversion(int(tabla[2][i]))
        i+=1
def conversion(decimal):
    binario=''
    aux=""
    while decimal>0:
        binario+=str(decimal%2)
        decimal=int(decimal/2)
    binario=binario[::-1]
    if len (binario)<22:
        for i in range(len(binario),22):
            aux+="0"
        binario=aux+binario
    return binario
def cruza(p,m):
    h1=""
    h2=""
    retorno=[]
    indice=0
    while indice<12 and indice<len(p):
        h1+=p[indice]
        indice+=1
    while indice<len(m):
        h1+=m[indice]
        indice+=1
        
    indice=0
    while indice<12 and indice<len(m):
        h2+=m[indice]
        indice+=1
    while indice<len(p):
        h2+=p[indice]
        indice+=1
    retorno.append(h1)
    retorno.append(h2)
    return retorno

def nuevasResultados(tabla):
    parejas=[]
    cont=0
    while cont<1:
        nuevaPareja=[]
        p=0
        m=1
        i=0
        while i<cont:
            if parejas[0][i]==p and parejas[1][i]==m:
                continue
            i+=1
        nuevaGeneracion=cruza(tabla[4][p],tabla[4][m])
        if nuevaGeneracion[0]==tabla[4][p] or nuevaGeneracion[0]==tabla[4][m] or nuevaGeneracion[1]==tabla[4][p] or nuevaGeneracion[1]==tabla[4][m]:
            continue
        print("padre:\t"+str(tabla[4][p]))
        print("madre:\t"+str(tabla[4][m]))
        print("Hijo 1:\t"+str(nuevaGeneracion[0]))
        print("Hijo 2:\t"+str(nuevaGeneracion[1]))
        print()
        nuevaPareja.append(p)
        nuevaPareja.append(m)
        parejas.append(parejas)
        cont+=1
##################################################################################################################
#datos del programa
fx=[]
fy=[]
fun=[]
grado=[]
binario=[]
tabla=[]
for i in range(10):
    x=aleatorios(10)
    y=aleatorios(10)
    z=f(x,y)
    fx.append(x) 
    fy.append(y)
    fun.append(z)
    grado.append(0)
    binario.append(0)
    tabla.append(fx)
    tabla.append(fy)
    tabla.append(fun)
    tabla.append(grado)
    tabla.append(binario)
##############################################################################################################################
#salidas
imprimir(tabla)
print("\n\ntabla con el grado de pertenecia")
SelectionSort(tabla)
CalcularGrado(tabla)
imprimir(tabla)
sumagrado=round(suma(tabla),1)
print ("la sumatoria de los grados es "+str(sumagrado))
print("la conversion a binario es ")
ConvertirColumnaABinario(tabla)
imprimir(tabla) 
nuevasResultados(tabla)
# Out:
# x		y		 f(x,y)		grado de pertenencia 		binario
# 34		17		29478		0				0
# 36		43		122292		0				0
# 95		96		1741920		0				0
# 75		52		495300		0				0
# 1		92		8556		0				0
# 24		18		18144		0				0
# 49		71		417480		0				0
# 8		21		4872		0				0
# 20		66		113520		0				0
# 35		7		10290		0				0
#
#
#
# tabla con el grado de pertenecia
# x		y		 f(x,y)		grado de pertenencia 		binario
# 95		96		1741920		0.58812				0
# 75		52		495300		0.16723				0
# 49		71		417480		0.14095				0
# 36		43		122292		0.04129				0
# 20		66		113520		0.03833				0
# 34		17		29478		0.00995				0
# 24		18		18144		0.00613				0
# 35		7		10290		0.00347				0
# 1		92		8556		0.00289				0
# 8		21		4872		0.00164				0
#
# la sumatoria de los grados es 1.0
# la conversion a binario es
# x		y		 f(x,y)		grado de pertenencia 		binario
# 95		96		1741920		0.58812				0110101001010001100000
# 75		52		495300		0.16723				0001111000111011000100
# 49		71		417480		0.14095				0001100101111011001000
# 36		43		122292		0.04129				0000011101110110110100
# 20		66		113520		0.03833				0000011011101101110000
# 34		17		29478		0.00995				0000000111001100100110
# 24		18		18144		0.00613				0000000100011011100000
# 35		7		10290		0.00347				0000000010100000110010
# 1		92		8556		0.00289				0000000010000101101100
# 8		21		4872		0.00164				0000000001001100001000
#
# padre:	0110101001010001100000
# madre:	0001111000111011000100
# Hijo 1:	0110101001011011000100
# Hijo 2:	0001111000110001100000
