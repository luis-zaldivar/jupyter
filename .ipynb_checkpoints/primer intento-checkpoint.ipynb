# %%
import random
from random import randint
#funciones
def aleatorios(n):
    return random.randrange(100)
def f(x,y):
    return (x**2*(y))+(y**2*(x))
def imprimir(tab):
    print("x\t\ty\t\t f(x,y)\t\tgrado de pertenencia \t\tbinario")
    for i in range(10):
        print(str(tabla[0][i])+"\t\t",end="")
        print(str(tabla[1][i])+"\t\t",end="")
        print(str(tabla[2][i])+"\t\t",end="")
        print(str(tabla[3][i])+"\t\t",end="")
        print(str(tabla[4][i]))
    print()
def SelectionSort(tabla):
    #Ordenar con el metodo de selection sort
    for i in range(10):
        valorMaximo=0
        posicionMaximo=0
        j=i
        while j<10:
            if tabla[2][j]>valorMaximo:
                valorMaximo=tabla[2][j]
                posicionMaximo=j
            j+=1
        tabla[0][i],tabla[0][posicionMaximo]=tabla[0][posicionMaximo],tabla[0][i]
        tabla[1][i],tabla[1][posicionMaximo]=tabla[1][posicionMaximo],tabla[1][i]
        tabla[2][i],tabla[2][posicionMaximo]=tabla[2][posicionMaximo],tabla[2][i]

    
    
def CalcularGrado(tabla):
    sumatoria=0
    for valor in tabla[2]:
        sumatoria+=valor
    i=0   
    while i<10:
        tabla[3][i]=round(tabla[2][i]/sumatoria,2)
        i=i+1
def suma(lista):
    s=0
    for i in range (10):
        s=s+(tabla[3][i])
    return s
def ConvertirColumnaABinario(tabla):
    i=0
    while i<10:
        tabla[4][i]=conversion(int(tabla[2][i]))
        i+=1
def conversion(decimal):
    binario=''
    while decimal //2!=0:
        binario=str(decimal % 2)+binario
        decimal=decimal//2
    return str(decimal)+binario
def Mezclar(p,m):
    h1=""
    h2=""
    retorno=[]
    indice=0
    while indice<2 and indice<len(p):
        h1+=p[indice]
        indice+=1
    while indice<len(m):
        h1+=m[indice]
        indice+=1
        
    indice=0
    while indice<2 and indice<len(m):
        h2+=m[indice]
        indice+=1
    while indice<len(p):
        h2+=p[indice]
        indice+=1
    retorno.append(h1)
    retorno.append(h2)
    return retorno

def GenerarHijos(tabla):
    parejas=[]
    cont=0
    while cont<4:
        nuevaPareja=[]
        p=randint(0,9)
        m=randint(0,9)
        while m==p:
            m=randint(0,9)
        i=0
        while i<cont:
            if parejas[0][i]==p and parejas[1][i]==m:
                continue
            i+=1
        nuevaGeneracion=Mezclar(tabla[4][p],tabla[4][m])
        if nuevaGeneracion[0]==tabla[4][p] or nuevaGeneracion[0]==tabla[4][m] or nuevaGeneracion[1]==tabla[4][p] or nuevaGeneracion[1]==tabla[4][m]:
            continue
        print("padre:\t"+str(tabla[4][p]))
        print("madre:\t"+str(tabla[4][m]))
        print("Hijo 1:\t"+str(nuevaGeneracion[0]))
        print("Hijo 2:\t"+str(nuevaGeneracion[1]))
        print()
        nuevaPareja.append(p)
        nuevaPareja.append(m)
        parejas.append(parejas)
        cont+=1
##################################################################################################################
#datos del programa
fx=[]
fy=[]
fun=[]
grado=[]
binario=[]
tabla=[]
for i in range(10):
    x=aleatorios(10)
    y=aleatorios(10)
    z=f(x,y)
    fx.append(x) 
    fy.append(y)
    fun.append(z)
    grado.append(0)
    binario.append(0)
    tabla.append(fx)
    tabla.append(fy)
    tabla.append(fun)
    tabla.append(grado)
    tabla.append(binario)
##############################################################################################################################
#salidas
imprimir(tabla)
print("\n\ntabla con el grado de pertenecia")
SelectionSort(tabla)
CalcularGrado(tabla)
imprimir(tabla)
sumagrado=suma(tabla)
print ("la sumatoria de los grados es "+str(sumagrado))
print("la conversion a binario es ")
ConvertirColumnaABinario(tabla)
imprimir(tabla) 
GenerarHijos(tabla)
# Out:
# x		y		 f(x,y)		grado de pertenencia 		binario
# 74		30		230880		0		0
# 60		56		389760		0		0
# 60		18		84240		0		0
# 87		56		696696		0		0
# 12		38		22800		0		0
# 28		50		109200		0		0
# 66		4		18480		0		0
# 72		48		414720		0		0
# 73		24		169944		0		0
# 54		55		323730		0		0
#
#
#
# tabla con el grado de pertenecia
# x		y		 f(x,y)		grado de pertenencia 		binario
# 87		56		696696		0.28		0
# 72		48		414720		0.17		0
# 60		56		389760		0.16		0
# 54		55		323730		0.13		0
# 74		30		230880		0.09		0
# 73		24		169944		0.07		0
# 28		50		109200		0.04		0
# 60		18		84240		0.03		0
# 12		38		22800		0.01		0
# 66		4		18480		0.01		0
#
# la sumatoria de los grados es 0.9900000000000002
# la conversion a binario es
# x		y		 f(x,y)		grado de pertenencia 		binario
# 87		56		696696		0.28		10101010000101111000
# 72		48		414720		0.17		1100101010000000000
# 60		56		389760		0.16		1011111001010000000
# 54		55		323730		0.13		1001111000010010010
# 74		30		230880		0.09		111000010111100000
# 73		24		169944		0.07		101001011111011000
# 28		50		109200		0.04		11010101010010000
# 60		18		84240		0.03		10100100100010000
# 12		38		22800		0.01		101100100010000
# 66		4		18480		0.01		100100000110000
#
# padre:	101100100010000
# madre:	1100101010000000000
# Hijo 1:	1000101010000000000
# Hijo 2:	111100100010000
#
# padre:	11010101010010000
# madre:	1011111001010000000
# Hijo 1:	1111111001010000000
# Hijo 2:	10010101010010000
#
# padre:	1100101010000000000
# madre:	1001111000010010010
# Hijo 1:	1101111000010010010
# Hijo 2:	1000101010000000000
#
# padre:	101001011111011000
# madre:	11010101010010000
# Hijo 1:	10010101010010000
# Hijo 2:	111001011111011000
