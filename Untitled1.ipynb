# %%
import random

def f(x,y):
    s=((x**2)+(2*y))
    return s
def aleatorios(n):
    return random.randrange(1,100)
def imprimir(tab):
    print("x\t\ty\t\t f(x,y)")
    for i in range(10):
        print(str(tab[0][i])+"\t\t",end="")
        print(str(tab[1][i])+"\t\t",end="")
        print(str(tab[2][i])+"\t\t")
    print()  

def verificar(comparar,arreglo):
    for Actual in arreglo:
        if arreglo==comparar:
            return True
        else:
            return False 
        
def ordenar(arreglo):
    for i in range(0,len(arreglo)-1):
        # recorremos todos los elementos desde el ultimo hasta el primero
        for j in range(len(arreglo)-1,i,-1):
            # si el valor es mas pequeño que el anterior lo intercambia
            if arreglo[j]<arreglo[j-1]:
                arreglo[j-1],arreglo[j]=arreglo[j],arreglo[j-1]
    print(arreglo)
        
    
def torneo(tabla):
    numeros = []
    # Le agregamos 3 números
    con=1
    while con<=3:
        numero = random.randrange(0,10)
        z1=tabla[2][numero]
        if verificar(z1,numeros):
            continue
        numeros.append(z1)
        con+=1
    ordenar(numeros)
    for i in range(3):
        print(numeros[i])
    numeros.sort()
    ####################
    
            
        
    ###################
    """for i in range(10):
        if (numeros[1]==todo[2][i]):
            print("la posiscion 2: ",i)
        if(numeros[2]==todo[2][i]):
            print("la posicion 1:",i)
"""
    
fx=[]
fy=[]
funcion=[]
todo=[]
for i in range(20):
    v1=aleatorios(20)
    v2=aleatorios(20)
    v3=f(v1,v2)
    fx.append(v1) 
    fy.append(v2)
    funcion.append(v3)
    todo.append(fx)
    todo.append(fy)
    todo.append(funcion)
imprimir(todo)
torneo(todo)
# Out:
# x		y		 f(x,y)
# 96		97		9410
# 51		71		2743
# 42		48		1860
# 55		59		3143
# 63		84		4137
# 22		22		528
# 39		23		1567
# 14		22		240
# 97		4		9417
# 40		80		1760
#
# [1567, 4137, 9410]
# 1567
# 4137
# 9410
