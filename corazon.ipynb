# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.arange(-4.5,4.5,0.05)
y= np.sqrt(1-(pow((abs(x)-1),2)))
y1= np.arccos(1-abs(x))-np.pi
plt.plot(x,y)
plt.plot(x,y1)
plt.show()
# Out:
# c:\python37\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in sqrt
#   """
# c:\python37\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in arccos
